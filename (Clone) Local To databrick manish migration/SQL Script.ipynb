# %%
# %sql
SHOW CATALOGS;

# %%
# %sql
use CATALOG youtube_project

# %%
# %sql
SHOW SCHEMAS;

# %%
# %sql
use schema youtube_project_database

# %%
youtube_project.youtube_project_database

# %%
# %sql
CREATE TABLE customer (
    customer_id INT,
    first_name VARCHAR(50),
    last_name VARCHAR(50),
    address VARCHAR(255),
    pincode VARCHAR(10),
    phone_number VARCHAR(20),
    customer_joining_date DATE
)
USING DELTA
LOCATION 'youtube_project.youtube_project_database';

# %%
# %sql
USE youtube_project.youtube_project_database;

CREATE TABLE customer (
    customer_id INT,
    first_name STRING,
    last_name STRING,
    address STRING,
    pincode STRING,
    phone_number STRING,
    customer_joining_date DATE
)
USING DELTA;

# %%
# %sql
INSERT INTO customer VALUES (1, 'Saanvi', 'Krishna', 'Delhi', '122009', '9173121081', '2021-01-20');
INSERT INTO customer VALUES (2, 'Dhanush', 'Sahni', 'Delhi', '122009', '9155328165', '2022-03-27');
INSERT INTO customer VALUES (3, 'Yasmin', 'Shan', 'Delhi', '122009', '9191478300', '2023-04-08');
INSERT INTO customer VALUES (4, 'Vidur', 'Mammen', 'Delhi', '122009', '9119017511', '2020-10-12');
INSERT INTO customer VALUES (5, 'Shamik', 'Doctor', 'Delhi', '122009', '9105180499', '2022-10-30');
INSERT INTO customer VALUES (6, 'Ryan', 'Dugar', 'Delhi', '122009', '9142616565', '2020-08-10');
INSERT INTO customer VALUES (7, 'Romil', 'Shanker', 'Delhi', '122009', '9129451313', '2021-10-29');
INSERT INTO customer VALUES (8, 'Krish', 'Tandon', 'Delhi', '122009', '9145683399', '2020-01-08');
INSERT INTO customer VALUES (9, 'Divij', 'Garde', 'Delhi', '122009', '9141984713', '2020-11-10');
INSERT INTO customer VALUES (10, 'Hunar', 'Tank', 'Delhi', '122009', '9169808085', '2023-01-27');
INSERT INTO customer VALUES (11, 'Zara', 'Dhaliwal', 'Delhi', '122009', '9129776379', '2023-06-13');
INSERT INTO customer VALUES (12, 'Sumer', 'Mangal', 'Delhi', '122009', '9138607933', '2020-05-01');
INSERT INTO customer VALUES (13, 'Rhea', 'Chander', 'Delhi', '122009', '9103434731', '2023-08-09');
INSERT INTO customer VALUES (14, 'Yuvaan', 'Bawa', 'Delhi', '122009', '9162077019', '2023-02-18');
INSERT INTO customer VALUES (15, 'Sahil', 'Sabharwal', 'Delhi', '122009', '9174928780', '2021-03-16');
INSERT INTO customer VALUES (16, 'Tiya', 'Kashyap', 'Delhi', '122009', '9105126094', '2023-03-23');
INSERT INTO customer VALUES (17, 'Kimaya', 'Lala', 'Delhi', '122009', '9115616831', '2021-03-14');
INSERT INTO customer VALUES (18, 'Vardaniya', 'Jani', 'Delhi', '122009', '9125068977', '2022-07-19');
INSERT INTO customer VALUES (19, 'Indranil', 'Dutta', 'Delhi', '122009', '9120667755', '2023-07-18');
INSERT INTO customer VALUES (20, 'Kavya', 'Sachar', 'Delhi', '122009', '9157628717', '2022-05-04');
INSERT INTO customer VALUES (21, 'Manjari', 'Sule', 'Delhi', '122009', '9112525501', '2023-02-12');
INSERT INTO customer VALUES (22, 'Akarsh', 'Kalla', 'Delhi', '122009', '9113226332', '2021-03-05');
INSERT INTO customer VALUES (23, 'Miraya', 'Soman', 'Delhi', '122009', '9111455455', '2023-07-06');
INSERT INTO customer VALUES (24, 'Shalv', 'Chaudhary', 'Delhi', '122009', '9158099495', '2021-03-14');
INSERT INTO customer VALUES (25, 'Jhanvi', 'Bava', 'Delhi', '122009', '9110074097', '2022-07-14');

# %%
# %sql
select * from customer

# %%
# %sql
CREATE TABLE store (
    id INT,
    address STRING,
    store_pincode STRING,
    store_manager_name STRING,
    store_opening_date DATE,
    reviews STRING
);

--data of store table
INSERT INTO store (id, address, store_pincode, store_manager_name, store_opening_date, reviews)
VALUES
    (121,'Delhi', '122009', 'Manish', '2022-01-15', 'Great store with a friendly staff.'),
    (122,'Delhi', '110011', 'Nikita', '2021-08-10', 'Excellent selection of products.'),
    (123,'Delhi', '201301', 'vikash', '2023-01-20', 'Clean and organized store.'),
    (124,'Delhi', '400001', 'Rakesh', '2020-05-05', 'Good prices and helpful staff.');

# %%
# %sql
CREATE TABLE product (
    id INT,
    name STRING,
    current_price DECIMAL(10,2),
    old_price DECIMAL(10,2),
    created_date TIMESTAMP,
    updated_date TIMESTAMP,
    expiry_date DATE
)
USING DELTA;

# %%
# %sql
INSERT INTO product (id, name, current_price, old_price, created_date, updated_date, expiry_date)
VALUES
    (1, 'quaker oats', 212, 212, '2022-05-15', NULL, '2025-01-01'),
    (2, 'sugar', 50, 50, '2021-08-10', NULL, '2025-01-01'),
    (3, 'maida', 20, 20, '2023-03-20', NULL, '2025-01-01'),
    (4, 'besan', 52, 52, '2020-05-05', NULL, '2025-01-01'),
    (5, 'refined oil', 110, 110, '2022-01-15', NULL, '2025-01-01'),
    (6, 'clinic plus', 1.5, 1.5, '2021-09-25', NULL, '2025-01-01'),
    (7, 'dantkanti', 100, 100, '2023-07-10', NULL, '2025-01-01'),
    (8, 'nutrella', 40, 40, '2020-11-30', NULL, '2025-01-01');

# %%
# %sql
CREATE TABLE sales_team (
    id INT,
    first_name STRING,
    last_name STRING,
    manager_id INT,
    is_manager STRING,
    address STRING,
    pincode STRING,
    joining_date DATE
)
USING DELTA;

# %%
# %sql
INSERT INTO sales_team (id, first_name, last_name, manager_id, is_manager, address, pincode, joining_date)
VALUES
    (1, 'Rahul', 'Verma', 10, 'N', 'Delhi', '122007', '2020-05-01'),
    (2, 'Priya', 'Singh', 10, 'N', 'Delhi', '122007', '2020-05-01'),
    (3, 'Amit', 'Sharma', 10, 'N', 'Delhi', '122007', '2020-05-01'),
    (4, 'Sneha', 'Gupta', 10, 'N', 'Delhi', '122007', '2020-05-01'),
    (5, 'Neha', 'Kumar', 10, 'N', 'Delhi', '122007', '2020-05-01'),
    (6, 'Vijay', 'Yadav', 10, 'N', 'Delhi', '122007', '2020-05-01'),
    (7, 'Anita', 'Malhotra', 10, 'N', 'Delhi', '122007', '2020-05-01'),
    (8, 'Alok', 'Rajput', 10, 'N', 'Delhi', '122007', '2020-05-01'),
    (9, 'Monica', 'Jain', 10, 'N', 'Delhi', '122007', '2020-05-01'),
    (10, 'Rajesh', 'Gupta', 10, 'Y', 'Delhi', '122007', '2020-05-01');

# %%
# %sql
select count(*) from youtube_project.youtube_project_database.customers_data_mart

# %%
# %sql
select count(*) from customers_data_mart

# %%
# %sql
DESCRIBE HISTORY youtube_project.youtube_project_database.customers_data_mart;

# %%
# %sql
CREATE TABLE customers_data_mart (
    customer_id INT ,
    full_name VARCHAR(100),
    address VARCHAR(200),
    phone_number VARCHAR(20),
    sales_date_month string,
    total_sales DECIMAL(10, 2)
);

# %%
# %sql
drop table youtube_project.youtube_project_database.sales_team_data_mart

# %%
# %sql CREATE TABLE sales_team_data_mart (
    store_id INT,
    sales_person_id INT,
    full_name VARCHAR(255),
    sales_month VARCHAR(10),
    total_sales DOUBLE,
    incentive DOUBLE
);

# %%
# %sql
CREATE TABLE product_staging_table (
    id INT,
    file_name VARCHAR(255),
    file_location VARCHAR(255),
    created_date TIMESTAMP ,
    updated_date TIMESTAMP ,
    status VARCHAR(1)
);

# %%
# %sql
truncate table  workspace.default.product_staging_table

# %%
# %sql
select * from workspace.default.product_staging_table

# %%
# %sql
select * from youtube_project.youtube_project_database.customers_data_mart

# %%
from datetime import datetime
import pytz

ist = pytz.timezone('Asia/Kolkata')

current_date = datetime.now(ist)

formatted_date = current_date.strftime("%Y-%m-%d %H:%M:%S")

print(formatted_date)
